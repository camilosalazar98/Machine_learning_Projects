# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import datasets
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')

    # highlight test samples
    if test_idx:
        # plot all samples
        X_test, y_test = X[test_idx, :], y[test_idx]

        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    c='',
                    edgecolor='black',
                    alpha=1.0,
                    linewidth=1,
                    marker='o',
                    s=100, 
                    label='test set')

# %%
iris = datasets.load_iris()
X_0 = iris.data[:, [0,0]]
y_0 = iris.target
#print(X)
print('Class labels:', np.unique(y_))


#spilt our training data
X_train_0, X_test_0, y_train_0, y_test_0 = train_test_split(
    X_0, y_0, test_size=0.3, random_state=1, stratify=y_0)

#Standardize features
sc = StandardScaler()
sc.fit(X_train_0)
X_train_std_0 = sc.transform(X_train_0)
X_test_std_0 = sc.transform(X_test_0)



X_combined_std_0 = np.vstack((X_train_std_0, X_test_std_0))
y_combined_0 = np.hstack((y_train_0, y_test_0))


from sklearn.linear_model import LogisticRegression

lr_0 = LogisticRegression(C=450.0, random_state=1,penalty='l1')
lr_0.fit(X_train_std_0, y_train_0)

plot_decision_regions(X_combined_std_0, y_combined_0,classifier=lr_0, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_06.png', dpi=300)
plt.show()
lr_0.score(X_combined_std_0,y_combined_0)
# Out:
# Class labels: [0 1 2]
# 0.71333333333333337

# %%
X_ = iris.data[:, [0,1]]
y_ = iris.target
#print(X)
print('Class labels:', np.unique(y_))


#spilt our training data
X_train, X_test, y_train, y_test = train_test_split(
    X_, y_, test_size=0.3, random_state=1, stratify=y_)

#Standardize features
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)



X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(C=120.0, random_state=1,penalty='l2')
lr.fit(X_train_std, y_train)

plot_decision_regions(X_combined_std, y_combined,classifier=lr, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_06.png', dpi=300)
plt.show()
lr.score(X_combined_std,y_combined)
# Out:
# Class labels: [0 1 2]
# 0.82666666666666666

# %%
X_1 = iris.data[:,[0,2]]
y_1 = iris.target
#print(X)

#spilt our training data
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X_1, y_1, test_size=0.3, random_state=1, stratify=y_1)

#Standardize features
sc_1 = StandardScaler()
sc_1.fit(X_train_1)
X_train_std_1 = sc.transform(X_train_1)
X_test_std_1 = sc.transform(X_test_1)



X_combined_std_1 = np.vstack((X_train_std_1, X_test_std_1))
y_combined_1 = np.hstack((y_train_1, y_test_1))

from sklearn.linear_model import LogisticRegression

lr_1 = LogisticRegression(C=210.0, random_state=1,penalty='l1').fit(X_train_std_1, y_train_1)

plot_decision_regions(X_combined_std_1, y_combined_1,classifier=lr_1, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_06.png', dpi=300)
plt.show()
lr_1.score(X_train_std_1,y_train_1)
# Out:
# 0.94285714285714284

# %%
X_2 = iris.data[:, [0,3]]
y_2 = iris.target
#print(X)

#spilt our training data
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(
    X_2, y_2, test_size=0.3, random_state=1, stratify=y_2)

#Standardize features
sc = StandardScaler()
sc.fit(X_train_2)
X_train_std = sc.transform(X_train_2)
X_test_std = sc.transform(X_test_2)



X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(C=1000.0, random_state=1,penalty='l2')
lr.fit(X_train_std, y_train)

plot_decision_regions(X_combined_std, y_combined,classifier=lr, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_06.png', dpi=300)
plt.show()
lr.score(X_train_std,y_train)
# Out:
# 0.93333333333333335

# %%
from sklearn.linear_model import LogisticRegression

X_3 = iris.data[:, [1,2]]
y_3 = iris.target
#print(X)

#spilt our training data
X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(X_3, y_3, test_size=0.3, random_state=1, stratify=y_3)

#Standardize features
sc = StandardScaler()
sc.fit(X_train_3)
X_train_std_3 = sc.transform(X_train_3)
X_test_std_3 = sc.transform(X_test_3)



X_combined_std_3 = np.vstack((X_train_std_3, X_test_std_3))
y_combined_3 = np.hstack((y_train_3, y_test_3))

lr_3 = LogisticRegression(C=100.0, random_state=1,penalty='l2')
lr_3.fit(X_train_std_3, y_train_3)


plot_decision_regions(X_combined_std_3, y_combined_3,classifier=lr_3, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_06.png', dpi=300)
print(lr_3.score(X_train_std_3,y_train_3))

plt.show()
# Out:
# 0.92380952381

# %%
X_4= iris.data[:, [1,3]]
y_4 = iris.target
#print(X)

#spilt our training data
X_train_4, X_test_4, y_train_4, y_test_4 = train_test_split(
    X_4, y_4, test_size=0.3, random_state=1, stratify=y_4)

#Standardize features
sc = StandardScaler()
sc.fit(X_train_4)
X_train_std_4 = sc.transform(X_train_4)
X_test_std_4 = sc.transform(X_test_4)



X_combined_std_4 = np.vstack((X_train_std_4, X_test_std_4))
y_combined_4 = np.hstack((y_train_4, y_test_4))

from sklearn.linear_model import LogisticRegression

lr_4 = LogisticRegression(C=5100.0, random_state=1,penalty='l2')
lr_4.fit(X_train_std_4, y_train_4)

print(lr_3.score(X_train_std_4,y_train_4))


plot_decision_regions(X_combined_std_4, y_combined_4,classifier=lr_4, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_06.png', dpi=300)
plt.show()
# Out:
# 0.942857142857

# %%
X_5 = iris.data[:, [0,0,0]]
y_5 = iris.target

#print(X)

#spilt our training data
X_train_5, X_test_5, y_train_5, y_test_5 = train_test_split(
    X_5, y_5, test_size=0.3, random_state=1, stratify=y_5)

#Standardize features
sc = StandardScaler()
sc.fit(X_train_5)
X_train_std_5 = sc.transform(X_train_5)
X_test_std_5 = sc.transform(X_test_5)



X_combined_std_5 = np.vstack((X_train_std_5, X_test_std_5))
y_combined_5 = np.hstack((y_train_5, y_test_5))

from sklearn.linear_model import LogisticRegression

lr_5 = LogisticRegression(C=50.0, random_state=1,penalty='l2')
lr_5.fit(X_train_std_5, y_train_5)
lr_5.score(X_train_std_5,y_train_5)
# Out:
# 0.75238095238095237

# %%
X_6 = iris.data[:, [0,1,2]]
y_6 = iris.target

#print(X)

#spilt our training data
X_train_6, X_test_6, y_train_6, y_test_6 = train_test_split(
    X_6, y_6, test_size=0.3, random_state=1, stratify=y_6)

#Standardize features
sc = StandardScaler()
sc.fit(X_train_6)
X_train_std_6 = sc.transform(X_train_6)
X_test_std_6 = sc.transform(X_test_6)



X_combined_std_6 = np.vstack((X_train_std_6, X_test_std_6))
y_combined_6 = np.hstack((y_train_6, y_test_6))

from sklearn.linear_model import LogisticRegression

lr_6 = LogisticRegression(C=150.0, random_state=1,penalty='l2')
lr_6.fit(X_train_std_6, y_train_6)
lr_6.score(X_train_std_6,y_train_6)
# Out:
# 0.92380952380952386

# %%
X_7 = iris.data[:, [0,1,3]]
y_7 = iris.target
#print(X)

#spilt our training data
X_train_7, X_test_7, y_train_7, y_test_7 = train_test_split(
    X_7, y_7, test_size=0.3, random_state=1, stratify=y_7)

#Standardize features
sc = StandardScaler()
sc.fit(X_train_7)
X_train_std_7 = sc.transform(X_train_7)
X_test_std_7 = sc.transform(X_test_7)



X_combined_std_7 = np.vstack((X_train_std_7, X_test_std_7))
y_combined_7 = np.hstack((y_train_7, y_test_7))

from sklearn.linear_model import LogisticRegression

lr_7 = LogisticRegression(C=1.0, random_state=1,penalty='l2')
lr_7.fit(X_train_std_7, y_train_7)
lr_7.score(X_train_std_7,y_train_7)
# Out:
# 0.90476190476190477

# %%
X_8 = iris.data[:, [0,2,3]]
y_8 = iris.target
#print(X)

#spilt our training data
X_train_8, X_test_8, y_train_8, y_test_8 = train_test_split(
    X_8, y_8, test_size=0.3, random_state=1, stratify=y_8)

#Standardize features
sc = StandardScaler()
sc.fit(X_train_8)
X_train_std_8 = sc.transform(X_train_8)
X_test_std_8 = sc.transform(X_test_8)



X_combined_std_8 = np.vstack((X_train_std_8, X_test_std_8))
y_combined_8 = np.hstack((y_train_8, y_test_8))

from sklearn.linear_model import LogisticRegression

lr_8 = LogisticRegression(C=100000.0, random_state=1)
lr_8.fit(X_train_std_8, y_train_8)
lr_8.score(X_train_std_8,y_train_8)
# Out:
# 0.95238095238095233

# %%
X_9 = iris.data[:, [1,2,3]]
y_9 = iris.target


#spilt our training data
X_train_9, X_test_9, y_train_9, y_test_9 = train_test_split(
    X_9, y_9, test_size=0.3, random_state=1, stratify=y_9)

#Standardize features
sc_9 = StandardScaler()
sc_9.fit(X_train_9)
X_train_std_9 = sc.transform(X_train_9)
X_test_std_9 = sc.transform(X_test_9)



X_combined_std_9 = np.vstack((X_train_std_9, X_test_std_9))
y_combined = np.hstack((y_train_9, y_test_9))

from sklearn.linear_model import LogisticRegression

lr_9 = LogisticRegression(C=10.0, random_state=1,penalty='l2')
lr_9.fit(X_train_std_9, y_train_9)
lr_9.score(X_train_std_9,y_train_9)
# Out:
# 0.93333333333333335

# %%
X_10 = iris.data[:,[0,1,2,3]]
y_10 = iris.target
#print(X)

#spilt our training data
X_train_10, X_test_10, y_train_10, y_test_10 = train_test_split(
    X_10, y_10, test_size=0.3, random_state=1, stratify=y_10)

#Standardize features
sc_10 = StandardScaler()
sc_10.fit(X_train_10)
X_train_std_10 = sc_10.transform(X_train_10)
X_test_std_10 = sc_10.transform(X_test_10)



X_combined_std_10 = np.vstack((X_train_std_10, X_test_std_10))
y_combined_10 = np.hstack((y_train_10, y_test_10))

from sklearn.linear_model import LogisticRegression

lr_10 = LogisticRegression(C=100000000.0, random_state=1,penalty='l2')
lr_10.fit(X_train_std_10, y_train_10)
lr_10.score(X_train_std_10,y_train_10)
# Out:
# 0.95238095238095233

# %% [markdown]
# Again I wasn't able to plot for the last for because the graph is only 2d and it isn't able to handle for dimensions as you stated in class.
#
#
# As I play around this the LogisticRegression algorithm I've notices adding more dimension to the algorithm allow it to classify features more accurate. The reasoning is you get a hyper plane which allows the algorithm to classify better. Which I found interesting then I change some of the C values which inverse-regularization parameter and the L1 and L2 parameter.The L1 and L2 are very useful method to handle collinearity (high correlation among features),  filter out noise from data, and eventually prevent over fitting.
# During experiment with the differnet case I've used L1 and L2 to help get a better score.
# When I did I’ve notice some change for the better. It wasn’t a change but it was a noticeable difference. One of the examples were when I was trying to classify the feature [0,1]. I first I changed it to c = 5 and penalty = l1. This resulted in the score on how well it classified 0.8 percent. I then also increase C= 1150 just to see what would happen. The score jumped too 0.82 which is a difference.
#
#
#
# **Note I left the percentage(score) on how well it did in the excel sheet
