# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn import datasets
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')

    # highlight test samples
    if test_idx:
        # plot all samples
        X_test, y_test = X[test_idx, :], y[test_idx]

        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    c='',
                    edgecolor='black',
                    alpha=1.0,
                    linewidth=1,
                    marker='o',
                    s=100, 
                    label='test set')

# %%
iris = datasets.load_iris()
X_ = iris.data[:, [0,1]]
y_ = iris.target
#print(X)
print('Class labels:', np.unique(y_))


#spilt our training data
X_train_, X_test_, y_train_, y_test_ = train_test_split(
    X_, y_, test_size=0.3, random_state=1, stratify=y_)

#Standardize features
sc_ = StandardScaler()
sc_.fit(X_train_)
X_train_std_ = sc_.transform(X_train_)
X_test_std_ = sc_.transform(X_test_)



X_combined_std_ = np.vstack((X_train_std_, X_test_std_))
y_combined_ = np.hstack((y_train_, y_test_))

from sklearn.svm import SVC
svm_ = SVC(kernel='poly', C=100.0, random_state=1)
svm_.fit(X_train_std_, y_train_)
plot_decision_regions(X_combined_std_,y_combined_,classifier=svm_,test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.show()
svm_.score(X_train_std_,y_train_)
# Out:
# Class labels: [0 1 2]
# 0.81904761904761902

# %%
iris = datasets.load_iris()
X_0 = iris.data[:, [0,2]]
y_0 = iris.target
#print(X)
#print('Class labels:', np.unique(y_0))


#spilt our training data
X_train_0, X_test_0, y_train_0, y_test_0 = train_test_split(
    X_0, y_0, test_size=0.3, random_state=1, stratify=y_0)

#Standardize features
sc = StandardScaler()
sc.fit(X_train_0)
X_train_std_0 = sc.transform(X_train_0)
X_test_std_0 = sc.transform(X_test_0)



X_combined_std_0 = np.vstack((X_train_std_0, X_test_std_0))
y_combined_0 = np.hstack((y_train_0, y_test_0))

from sklearn.svm import SVC
svm = SVC(kernel='linear', C=50.0, random_state=1)
svm.fit(X_train_std_0, y_train_0)
plot_decision_regions(X_combined_std_0,y_combined_0,classifier=svm,test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.show()
svm.score(X_train_std_0,y_train_0)
# Out:
# 0.96190476190476193

# %%
iris = datasets.load_iris()
X_1 = iris.data[:, [0,1,2]]
y_1 = iris.target
#print(X)
#print('Class labels:', np.unique(y_0))


#spilt our training data
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(
    X_1, y_1, test_size=0.3, random_state=1, stratify=y_1)

#Standardize features
sc_1 = StandardScaler()
sc_1.fit(X_train_1)
X_train_std_1 = sc_1.transform(X_train_1)
X_test_std_1 = sc_1.transform(X_test_1)



X_combined_std_1 = np.vstack((X_train_std_1, X_test_std_1))
y_combined_1 = np.hstack((y_train_1, y_test_1))

from sklearn.svm import SVC
svm_1 = SVC(kernel='rbf', C=1.0,gamma=0.2, random_state=1)
svm_1.fit(X_train_std_1, y_train_1)
svm_1.score(X_train_std_1,y_train_1)
# Out:
# 0.91428571428571426

# %%
iris = datasets.load_iris()
X_2 = iris.data[:, [0,1,2,3]]
y_2 = iris.target
#print(X)
#print('Class labels:', np.unique(y_0))


#spilt our training data
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(
    X_2, y_2, test_size=0.3, random_state=1, stratify=y_2)

#Standardize features
sc_2 = StandardScaler()
sc_2.fit(X_train_2)
X_train_std_2 = sc_2.transform(X_train_2)
X_test_std_2 = sc_2.transform(X_test_2)



X_combined_std_2 = np.vstack((X_train_std_2, X_test_std_2))
y_combined_2 = np.hstack((y_train_2, y_test_2))

from sklearn.svm import SVC
svm_2 = SVC(kernel='sigmoid', C=100.0,gamma=0.50, random_state=1)
svm_2.fit(X_train_std_2, y_train_2)
svm_2.score(X_train_std_2,y_train_2)
# Out:
# 0.76190476190476186

# %% [markdown]
# During my Project I tested different kernels to different feature to see what I would get. I’ve notice adding different kernels allow the algorithm to get a better accuracy. The kernels I’ve used were linear, rbf, sigmoid and ploy. While testing I was not able to plot more than three two feature a one time. The reason is because I can’t add more than two dimensions to a 2d mesh grid. I’ll also changed the gamma parameter which increase the influence of the training samples. When you change the gamma parameter to 50 it becomes .76 but when you try .1 it goes to .96. I realized also changing the C parameter which increase bias and lowers the variance in the model. The scores of the obtain was pretty good and they are all located in the excel sheet.
